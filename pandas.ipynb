# %% [markdown]
# # Olympic Analysis Project

# %% [markdown]
# In this project, we will analyse the Summer Olympics dataset by the International Olympics Committee. We will be coding along with this notebook.
#
# We will answer key stakeholder analysis questions for the project which could be used in a presentation.

# %% [markdown]
# ## Importing pandas

# %%
import pandas

# %%
pandas.__version__
# Out:
# '1.0.5'

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.0.5'

# %% [markdown]
# ## Pandas documentation

# %%
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit           : None
# python           : 3.6.10.final.0
# python-bits      : 64
# OS               : Darwin
# OS-release       : 18.7.0
# machine          : x86_64
# processor        : i386
# byteorder        : little
# LC_ALL           : en_US.UTF-8
# LANG             : en_GB.UTF-8
# LOCALE           : en_US.UTF-8
#
# pandas           : 1.0.5
# numpy            : 1.19.0
# pytz             : 2020.1
# dateutil         : 2.8.1
# pip              : 20.1.1
# setuptools       : 47.1.1
# Cython           : 0.29.20
# pytest           : None
# hypothesis       : None
# sphinx           : 3.1.2
# blosc            : None
# feather          : None
# xlsxwriter       : None
# lxml.etree       : None
# html5lib         : None
# pymysql          : None
# psycopg2         : None
# jinja2           : 2.11.2
# IPython          : 7.16.1
# pandas_datareader: None
# bs4              : None
# bottleneck       : None
# fastparquet      : None
# ...

# %%
pd.show_versions?

# %%
pd.read_csv?

# %%
import pandas as pd

# %%
# Data on the international olympics committee
df = pd.read_csv('olympics.csv', skiprows=4)

# %%
df
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
# dimensions, use shape method
df.shape
# Out:
# (29216, 10)

# %%
df.shape[1]
# Out:
# 10

# %%
#see the first few rows

df.head(10)
# Out:
#      City  Edition     Sport Discipline                Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming          HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming       HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming      DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming     MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming     CHASAPIS, Spiridon  GRE    Men
# 5  Athens     1896  Aquatics   Swimming  CHOROPHAS, Efstathios  GRE    Men
# 6  Athens     1896  Aquatics   Swimming          HAJOS, Alfred  HUN    Men
# 7  Athens     1896  Aquatics   Swimming       ANDREOU, Joannis  GRE    Men
# 8  Athens     1896  Aquatics   Swimming  CHOROPHAS, Efstathios  GRE    Men
# 9  Athens     1896  Aquatics   Swimming          NEUMANN, Paul  AUT    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
# City            29216 non-null object
# Edition         29216 non-null int64
# Sport           29216 non-null object
# Discipline      29216 non-null object
# Athlete         29216 non-null object
# NOC             29216 non-null object
# Gender          29216 non-null object
# Event           29216 non-null object
# Event_gender    29216 non-null object
# Medal           29216 non-null object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB

# %% [markdown]
# In which events did Jesse owens win a medal?

# %%
jesse = df[df.Athlete == 'OWENS, Jesse']

# %%
jesse.to_csv('jesse.csv')

# %%
 df[df.Athlete == 'HAJOS, Alfred']
# Out:
#      City  Edition     Sport Discipline        Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming  HAJOS, Alfred  HUN    Men
# 6  Athens     1896  Aquatics   Swimming  HAJOS, Alfred  HUN    Men
#
#              Event Event_gender Medal
# 0   100m freestyle            M  Gold
# 6  1200m freestyle            M  Gold

# %%
# which country has won the most men's gold medals in singles badminton over the years
# sort results alphabetically

df[ (df.Sport == 'Badminton') & (df.Medal == 'Gold') & (df.Gender == 'Men')]
# Out:
#             City  Edition      Sport Discipline                  Athlete  NOC  \
# 20031  Barcelona     1992  Badminton  Badminton            KIM, Moon-Soo  KOR
# 20032  Barcelona     1992  Badminton  Badminton           PARK, Joo-Bong  KOR
# 20045  Barcelona     1992  Badminton  Badminton        BUDI KUSUMA, Alan  INA
# 21771    Atlanta     1996  Badminton  Badminton     MAINAKY, Rexy Ronald  INA
# 21772    Atlanta     1996  Badminton  Badminton    SUBAGJA, Ricky Achmad  INA
# 21773    Atlanta     1996  Badminton  Badminton           KIM, Dong Moon  KOR
# 21787    Atlanta     1996  Badminton  Badminton  HOYER-LARSEN, Poul Erik  DEN
# 23701     Sydney     2000  Badminton  Badminton            GUNAWAN, Tony  INA
# 23702     Sydney     2000  Badminton  Badminton           WIJAYA, Candra  INA
# 23703     Sydney     2000  Badminton  Badminton               ZHANG, Jun  CHN
# 23717     Sydney     2000  Badminton  Badminton              JI, Xinpeng  CHN
# ...

# %%
goldmedal = df[(df.Sport == 'Badminton') & (df.Medal == 'Gold') & (df.Gender == 'Men')]

# %%
goldmedal.sort_values('Athlete')
# Out:
#             City  Edition      Sport Discipline                  Athlete  NOC  \
# 20045  Barcelona     1992  Badminton  Badminton        BUDI KUSUMA, Alan  INA
# 23701     Sydney     2000  Badminton  Badminton            GUNAWAN, Tony  INA
# 25718     Athens     2004  Badminton  Badminton             HA, Tae-Kwon  KOR
# 25734     Athens     2004  Badminton  Badminton          HIDAYAT, Taufik  INA
# 21787    Atlanta     1996  Badminton  Badminton  HOYER-LARSEN, Poul Erik  DEN
# 23717     Sydney     2000  Badminton  Badminton              JI, Xinpeng  CHN
# 27725    Beijing     2008  Badminton  Badminton             KIDO, Markis  INA
# 25719     Athens     2004  Badminton  Badminton           KIM, Dong Moon  KOR
# 21773    Atlanta     1996  Badminton  Badminton           KIM, Dong Moon  KOR
# 20031  Barcelona     1992  Badminton  Badminton            KIM, Moon-Soo  KOR
# 27727    Beijing     2008  Badminton  Badminton             LEE, Yongdae  KOR
# ...

# %%
#countries that won the most medals since 1996
df[df.Edition >= 1996].NOC.value_counts()
# Out:
# USA    1087
# RUS     638
# AUS     621
# GER     493
# CHN     467
#        ...
# ERI       1
# TOG       1
# PAN       1
# QAT       1
# TGA       1
# Name: NOC, Length: 109, dtype: int64

# %%
c1 = df[df.Edition >= 1996]

# %%
c1
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 21302  Atlanta     1996   Aquatics           Diving        XIAO, Hailiang
# 21303  Atlanta     1996   Aquatics           Diving        SAUTIN, Dmitry
# 21304  Atlanta     1996   Aquatics           Diving           HEMPEL, Jan
# 21305  Atlanta     1996   Aquatics           Diving     CLARK, Mary Ellen
# 21306  Atlanta     1996   Aquatics           Diving           FU, Mingxia
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender         Event Event_gender   Medal
# ...

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
c1.Gender.value_counts().plot('bar')
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: `Series.plot()` should not be called with positional arguments, only keyword arguments. The order of positional arguments will change in the future. Use `Series.plot(kind='bar')` instead of `Series.plot('bar',)`.
#   """Entry point for launching an IPython kernel.

# %%
import seaborn as sns

sns.countplot(data=c1, x=Gender)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-61-a84c0541e888> in <module>
# ----> 1 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
c1.Medal.value_counts()
# Out:
# USA    1087
# RUS     638
# AUS     621
# GER     493
# CHN     467
#        ...
# ERI       1
# TOG       1
# PAN       1
# QAT       1
# TGA       1
# Name: NOC, Length: 109, dtype: int64

# %%
c1.Medal.value_counts()
# Out:
# Bronze    2708
# Gold      2606
# Silver    2600
# Name: Medal, dtype: int64

# %%
c1.Gender.value_counts()
# Out:
# Men      4417
# Women    3497
# Name: Gender, dtype: int64

# %%
# Python's default plotting library is called Matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
c1.Gender.value_counts().plot('bar')
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: `Series.plot()` should not be called with positional arguments, only keyword arguments. The order of positional arguments will change in the future. Use `Series.plot(kind='bar')` instead of `Series.plot('bar',)`.
#   """Entry point for launching an IPython kernel.

# %%
c1.Medal.value_counts().plot('bar')
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: `Series.plot()` should not be called with positional arguments, only keyword arguments. The order of positional arguments will change in the future. Use `Series.plot(kind='bar')` instead of `Series.plot('bar',)`.
#   """Entry point for launching an IPython kernel.
